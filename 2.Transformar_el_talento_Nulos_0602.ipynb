# %%
import pandas as pd
import numpy as np
import re
from word2number import w2n
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Abrir el pd limpio
df = pd.read_csv('2_HR_DATA_clean.csv', index_col = 0)

# %%
df.sample(20)
# Out:
#       age attrition    business_travel  distance_from_home  education  \
# 362    31        no      travel_rarely                   7          4
# 1009   56        no         non-travel                   4          4
# 1406   42        no         non-travel                   2          3
# 169    55        no         non-travel                  26          4
# 1317   35        no         non-travel                  20          3
# 1095   36        no         non-travel                   5          4
# 732    26        no         non-travel                   1          2
# 686    53        no         non-travel                   3          4
# 1371   35        no      travel_rarely                   1          4
# 1294   40        no      travel_rarely                   2          3
# 207    33        no      travel_rarely                   1          3
# 641    40        no         non-travel                  14          2
# 357    55       yes         non-travel                   2          1
# 328    34        no         non-travel                  21          4
# 783    54        no         non-travel                   9          2
# 574    29       yes         non-travel                  27          3
# 97     36        no  travel_frequently                   3          3
# 240    39        no      travel_rarely                   3          2
# 1343   25       yes         non-travel                  19          2
# 701    41        no         non-travel                  10          2
#
#       education_field  environment_satisfaction gender  job_involvement  \
# 362               NaN                         2      M                2
# 1009              NaN                         4      F                3
# 1406          medical                         3      M                2
# 169   human resources                         3      M                4
# 1317              NaN                        20      M                2
# 1095    life sciences                         2      F                3
# 732           medical                         1      M                2
# 686               NaN                         3      M                3
# 1371          medical                         4      M                2
# 1294              NaN                         2      F                2
# 207           medical                         1      M                4
# 641     life sciences                         4      F                3
# 357           medical                         3      M                3
# 328               NaN                         4      M                4
# 783               NaN                         1      F                3
# 574         marketing                         2      F                3
# 97                NaN                         3      M                3
# 240               NaN                         3      M                2
# 1343        marketing                         3      M                2
# 701               NaN                         4      M                3
#
#       job_level                     job_role  job_satisfaction marital_status  \
# 362           1        sales representative                  3            NaN
# 1009          5                     manager                  1       divorced
# 1406          1       laboratory technician                  2        married
# 169           5                     manager                  2        married
# 1317          1       laboratory technician                  3        married
# 1095          3   healthcare representative                  1        married
# 732           1       laboratory technician                  1        married
# 686           4           research director                  3        married
# 1371          1       laboratory technician                  3            NaN
# 1294          2       laboratory technician                  3        married
# 207           2             sales executive                  1       divorced
# 641           2             sales executive                  1        married
# 357           2             sales executive                  4         single
# 328           2             sales executive                  4         single
# 783           2          research scientist                  3        married
# 574           3             sales executive                  4        married
# 97            1          research scientist                  2        married
# 240           2       laboratory technician                  3            NaN
# 1343          1        sales representative                  2        married
# 701           2             sales executive                  4         single
#
#       monthly_income_$  num_companies_worked over_time  percent_salary_hike  \
# 362             2329.0                     3       NaN                   15
# 1009               NaN                     4        No                   13
# 1406            4841.0                     4       NaN                   14
# 169                NaN                     4       Yes                   18
# 1317               NaN                     1        No                   18
# 1095               NaN                     4        No                   12
# 732                NaN                     1        No                   16
# 686            17584.0                     3       Yes                   16
# 1371            2258.0                     6        No                   12
# 1294            3448.0                     6        No                   22
# 207                NaN                     1       NaN                   22
# 641                NaN                     1        No                   15
# 357                NaN                     4       NaN                   16
# 328             5337.0                     1       NaN                   12
# 783             2897.0                     3        No                   11
# 574             7639.0                     1       NaN                   22
# 97              3692.0                     1        No                   12
# 240             3069.0                     0       NaN                   15
# 1343            2413.0                     1       Yes                   18
# 701                NaN                     7        No                   14
#
#       performance_rating  relationship_satisfaction standard_hours  \
# 362                  NaN                          2      part-time
# 1009                 3.0                          4      full-time
# 1406                 NaN                          2      full-time
# 169                  3.0                          1      part-time
# 1317                 3.0                          3      full-time
# 1095                 NaN                          3      full-time
# 732                  3.0                          1      full-time
# 686                  3.0                          4      full-time
# 1371                 3.0                          2      full-time
# 1294                 4.0                          2      full-time
# 207                  NaN                          1      full-time
# 641                  3.0                          3      full-time
# 357                  3.0                          3      part-time
# 328                  3.0                          4      part-time
# 783                  3.0                          3      full-time
# 574                  4.0                          4      full-time
# 97                   3.0                          3      full-time
# 240                  3.0                          4      full-time
# 1343                 NaN                          3      part-time
# 701                  3.0                          4      full-time
#
#       stock_option_level  total_working_years  worklife_balance  \
# 362                    0                  NaN               4.0
# 1009                   1                 28.0               3.0
# 1406                   1                  NaN               NaN
# 169                    1                 35.0               3.0
# 1317                   2                  1.0               3.0
# 1095                   2                  9.0               3.0
# 732                    2                  6.0               3.0
# 686                    3                 21.0               2.0
# 1371                   1                  NaN               3.0
# 1294                   1                  NaN               3.0
# 207                    1                  9.0               3.0
# 641                    1                  5.0               3.0
# 357                    0                  NaN               2.0
# 328                    0                 10.0               3.0
# 783                    2                  9.0               2.0
# 574                    3                 10.0               2.0
# 97                     0                 12.0               2.0
# 240                    1                  NaN               NaN
# 1343                   3                  NaN               3.0
# 701                    0                  NaN               3.0
#
#       years_at_company  years_since_last_promotion  years_with_curr_manager  \
# 362                  7                           5                        2
# 1009                 5                           4                        2
# 1406                 1                           0                        0
# 169                 10                           1                        4
# 1317                 1                           0                        0
# 1095                 3                           0                        2
# 732                  5                           1                        3
# 686                  5                           1                        3
# 1371                 8                           1                        7
# 1294                 1                           0                        0
# 207                  9                           0                        8
# 641                  5                           1                        2
# 357                  9                           7                        3
# 328                 10                           5                        7
# 783                  4                           2                        3
# 574                 10                           1                        9
# 97                  11                           0                        7
# 240                 10                           0                        7
# 1343                 1                           0                        0
# 701                 14                           1                       10
#
#      remote_work
# 362           no
# 1009         yes
# 1406         yes
# 169          yes
# 1317          no
# 1095         yes
# 732          yes
# 686          yes
# 1371         yes
# 1294         yes
# 207          yes
# 641          yes
# 357           no
# 328          yes
# 783           no
# 574          yes
# 97            no
# 240          yes
# 1343          no
# 701          yes

# %% [markdown]
# # TRATAMIENTO DE NULOS

# %%
print(df.isnull().sum())
# Out:
# age                             0
# attrition                       0
# business_travel                 0
# distance_from_home              0
# education                       0
# education_field               745
# environment_satisfaction        0
# gender                          0
# job_involvement                 0
# job_level                       0
# job_role                        0
# job_satisfaction                0
# marital_status                651
# monthly_income_$              843
# num_companies_worked            0
# over_time                     676
# percent_salary_hike             0
# performance_rating            195
# relationship_satisfaction       0
# standard_hours                  0
# stock_option_level              0
# total_working_years           526
# worklife_balance              108
# years_at_company                0
# years_since_last_promotion      0
# years_with_curr_manager         0
# remote_work                     0
# dtype: int64

# %%
len(df.columns)
# Out:
# 27

# %%
# 4. DataFrame con columnas que tienen nulos y su %:
porc_nulos = (df.isnull().sum() / df.shape[0]) * 100
df_nulos = pd.DataFrame(porc_nulos, columns=["%_nulos"])
print("\nColumnas con nulos y su porcentaje:")
display(df_nulos[df_nulos["%_nulos"] > 0])

# 5. Columnas categóricas con nulos
print("\nColumnas categóricas con nulos:")
nulos_esta_cat = df[df.columns[df.isnull().any()]].select_dtypes(include="O").columns
print(nulos_esta_cat)

# 6. Columnas numéricas con nulos
print("\nColumnas numéricas con nulos:")
nulos_esta_num = df[df.columns[df.isnull().any()]].select_dtypes(include=np.number).columns
print(nulos_esta_num)
# Out:
# Columnas con nulos y su porcentaje:
#                        %_nulos
# education_field      46.158612
# marital_status       40.334572
# monthly_income_$     52.230483
# over_time            41.883519
# performance_rating   12.081784
# total_working_years  32.589839
# worklife_balance      6.691450
# Columnas categóricas con nulos:
# Index(['education_field', 'marital_status', 'over_time'], dtype='object')
#
# Columnas numéricas con nulos:
# Index(['monthly_income_$', 'performance_rating', 'total_working_years',
#        'worklife_balance'],
#       dtype='object')

# %% [markdown]
# # Categoricas

# %%
for col in nulos_esta_cat:
    print(f"La distribución de las categorías (incluyendo nulos) para la columna", col)
    display(df[col].value_counts(dropna=False, normalize=True) * 100)  # Convertimos a porcentaje
    print("........................")
# Out:
# La distribución de las categorías (incluyendo nulos) para la columna education_field
# education_field
# NaN                 46.158612
# life sciences       21.623296
# medical             17.100372
# marketing            6.443618
# technical degree     4.275093
# other                3.655514
# human resources      0.743494
# Name: proportion, dtype: float64
# ........................
# La distribución de las categorías (incluyendo nulos) para la columna marital_status
# marital_status
# NaN         40.334572
# married     27.199504
# single      20.136307
# divorced    12.329616
# Name: proportion, dtype: float64
# ........................
# La distribución de las categorías (incluyendo nulos) para la columna over_time
# over_time
# No     42.255266
# NaN    41.883519
# Yes    15.861214
# Name: proportion, dtype: float64
# ........................

# %%
# cambiamos los nulos por "unknown"
columnas_desconocido = ["education_field", "marital_status", "over_time"]
for col in columnas_desconocido:
    df[col] = df[col].fillna('unknown')

# %%
# comprobar nulos
columnas_object_con_nulos = df[df.columns[df.isnull().any()]].select_dtypes(include = "O").columns
columnas_object_con_nulos
# Out:
# Index([], dtype='object')

# %% [markdown]
# # Numericas

# %%
columnas_number_con_nulos = df[df.columns[df.isnull().any()]].select_dtypes(include = "number").columns
columnas_number_con_nulos
# Out:
# Index(['monthly_income_$', 'performance_rating', 'total_working_years',
#        'worklife_balance'],
#       dtype='object')

# %%
df[columnas_number_con_nulos].isnull().sum() / df.shape[0]
# Out:
# monthly_income_$       0.522305
# performance_rating     0.120818
# total_working_years    0.325898
# worklife_balance       0.066914
# dtype: float64

# %%
# lo siguiente que tendríamos que hacer es ver si dentro de las columnas donde tenemos nulos tenemos valores atípicos. 
# Para hacer esto lo mejor es usar visualización, sin embargo, todavía no hemos aprendido (lo haremos mañana). 
# Por lo tanto, el código que tenéis a continuación no es necesario que lo entendais. 
fig, axes = plt.subplots(nrows = 2, ncols = 3, figsize = (20,10)) 
axes = axes.flat
for indice, col in enumerate(columnas_number_con_nulos):
    sns.boxplot(x = col, data = df, ax = axes[indice])
    
plt.tight_layout()
fig.delaxes(axes[-1]);

# %%
for col in list(columnas_number_con_nulos):
    plt.figure(figsize=(8, 5))
    plt.hist(df[col].dropna(), bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Histograma de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.show()

# %%
for col in nulos_esta_num:
    print(f"La distribución de las categorías (incluyendo nulos) para la columna", col)
    display(df[col].value_counts(dropna=False, normalize=True) * 100)  # Convertimos a porcentaje
    print("........................")
# Out:
# La distribución de las categorías (incluyendo nulos) para la columna monthly_income_$
# monthly_income_$
# NaN        52.230483
# 6347.0      0.247831
# 5304.0      0.247831
# 2657.0      0.185874
# 2258.0      0.185874
# 5405.0      0.123916
# 8224.0      0.123916
# 2610.0      0.123916
# 5731.0      0.123916
# 2539.0      0.123916
# 2376.0      0.123916
# 11713.0     0.123916
# 2216.0      0.123916
# 19189.0     0.123916
# 8793.0      0.123916
# 3452.0      0.123916
# 2070.0      0.123916
# 2587.0      0.123916
# 4960.0      0.123916
# 11159.0     0.123916
# 5396.0      0.123916
# 2782.0      0.123916
# 4197.0      0.123916
# 9434.0      0.123916
# 5337.0      0.123916
# 2741.0      0.123916
# 2791.0      0.123916
# 5828.0      0.123916
# 3420.0      0.123916
# 2033.0      0.123916
# 2821.0      0.123916
# 7756.0      0.123916
# 2042.0      0.123916
# 6632.0      0.123916
# 7587.0      0.123916
# 4335.0      0.123916
# 5980.0      0.123916
# 4244.0      0.123916
# 5228.0      0.123916
# 2700.0      0.123916
# 2909.0      0.123916
# 2404.0      0.123916
# 2377.0      0.123916
# 2366.0      0.123916
# 2329.0      0.123916
# 4294.0      0.123916
# 6725.0      0.123916
# 10325.0     0.123916
# 4447.0      0.123916
# 10845.0     0.123916
# 2380.0      0.123916
# 4805.0      0.123916
# 17861.0     0.123916
# 5605.0      0.123916
# 6162.0      0.123916
# 6410.0      0.123916
# 13212.0     0.123916
# 3034.0      0.123916
# 5974.0      0.123916
# 2119.0      0.123916
# 2144.0      0.123916
# 5373.0      0.123916
# 5257.0      0.123916
# 4682.0      0.123916
# 5769.0      0.123916
# 3539.0      0.123916
# 5468.0      0.123916
# 5813.0      0.123916
# 9667.0      0.123916
# 5154.0      0.123916
# 5675.0      0.123916
# 7314.0      0.123916
# 5055.0      0.123916
# 2455.0      0.123916
# 4941.0      0.123916
# 3983.0      0.123916
# 2904.0      0.123916
# 2696.0      0.123916
# 2308.0      0.123916
# 4051.0      0.123916
# 8392.0      0.123916
# 2654.0      0.123916
# 17046.0     0.123916
# 4306.0      0.123916
# 11510.0     0.123916
# 9613.0      0.123916
# 16015.0     0.123916
# 19045.0     0.123916
# 2218.0      0.123916
# 6538.0      0.123916
# 3904.0      0.123916
# 19406.0     0.123916
# 2543.0      0.123916
# 10965.0     0.123916
# 6755.0      0.123916
# 2174.0      0.123916
# 3760.0      0.123916
# 11103.0     0.123916
# 19537.0     0.061958
# 3180.0      0.061958
# 3445.0      0.061958
# 4440.0      0.061958
# 10448.0     0.061958
# 5399.0      0.061958
# 3978.0      0.061958
# 8103.0      0.061958
# 5507.0      0.061958
# 2062.0      0.061958
# 2662.0      0.061958
# 3902.0      0.061958
# 2105.0      0.061958
# 3591.0      0.061958
# 13116.0     0.061958
# 6294.0      0.061958
# 2760.0      0.061958
# 3907.0      0.061958
# 11244.0     0.061958
# 3477.0      0.061958
# 3433.0      0.061958
# 2305.0      0.061958
# 15972.0     0.061958
# 5505.0      0.061958
# 4374.0      0.061958
# 2166.0      0.061958
# 4898.0      0.061958
# 15202.0     0.061958
# 3117.0      0.061958
# 3312.0      0.061958
# 4855.0      0.061958
# 6392.0      0.061958
# 4069.0      0.061958
# 2580.0      0.061958
# 19081.0     0.061958
# 6651.0      0.061958
# 4262.0      0.061958
# 2400.0      0.061958
# 3681.0      0.061958
# 3447.0      0.061958
# 19513.0     0.061958
# 2659.0      0.061958
# 8847.0      0.061958
# 2045.0      0.061958
# 4851.0      0.061958
# 8120.0      0.061958
# 4577.0      0.061958
# 3708.0      0.061958
# 13770.0     0.061958
# 2297.0      0.061958
# 2450.0      0.061958
# 4342.0      0.061958
# 2572.0      0.061958
# 6500.0      0.061958
# 10527.0     0.061958
# 3894.0      0.061958
# 3162.0      0.061958
# 2546.0      0.061958
# 10650.0     0.061958
# 4317.0      0.061958
# 2024.0      0.061958
# 3058.0      0.061958
# 3929.0      0.061958
# 4425.0      0.061958
# 2328.0      0.061958
# 5940.0      0.061958
# 2622.0      0.061958
# 3212.0      0.061958
# 2911.0      0.061958
# 6931.0      0.061958
# 2176.0      0.061958
# 3230.0      0.061958
# 18665.0     0.061958
# 2789.0      0.061958
# 11935.0     0.061958
# 3149.0      0.061958
# 5324.0      0.061958
# 4382.0      0.061958
# 2553.0      0.061958
# 3867.0      0.061958
# 2080.0      0.061958
# 2096.0      0.061958
# 4627.0      0.061958
# 2302.0      0.061958
# 5071.0      0.061958
# 10596.0     0.061958
# 5467.0      0.061958
# 2394.0      0.061958
# 3629.0      0.061958
# 9362.0      0.061958
# 3229.0      0.061958
# 16422.0     0.061958
# 5647.0      0.061958
# 4400.0      0.061958
# 2066.0      0.061958
# 5486.0      0.061958
# 4538.0      0.061958
# 2743.0      0.061958
# 3375.0      0.061958
# 5562.0      0.061958
# 5933.0      0.061958
# 4403.0      0.061958
# 10934.0     0.061958
# 2022.0      0.061958
# 4256.0      0.061958
# 3580.0      0.061958
# 2899.0      0.061958
# 2799.0      0.061958
# 2207.0      0.061958
# 2811.0      0.061958
# 4377.0      0.061958
# 4240.0      0.061958
# 4227.0      0.061958
# 3917.0      0.061958
# 4969.0      0.061958
# 9957.0      0.061958
# 2660.0      0.061958
# 4422.0      0.061958
# 2269.0      0.061958
# 4766.0      0.061958
# 18303.0     0.061958
# 4777.0      0.061958
# 1052.0      0.061958
# 2461.0      0.061958
# 2596.0      0.061958
# 4728.0      0.061958
# 7351.0      0.061958
# 2827.0      0.061958
# 4787.0      0.061958
# 2853.0      0.061958
# 2290.0      0.061958
# 2107.0      0.061958
# 2210.0      0.061958
# 13191.0     0.061958
# 18265.0     0.061958
# 1118.0      0.061958
# 2600.0      0.061958
# 4163.0      0.061958
# 13194.0     0.061958
# 2479.0      0.061958
# 16627.0     0.061958
# 2083.0      0.061958
# 1009.0      0.061958
# 7861.0      0.061958
# 2642.0      0.061958
# 5121.0      0.061958
# 2694.0      0.061958
# 5094.0      0.061958
# 2274.0      0.061958
# 2314.0      0.061958
# 2008.0      0.061958
# 10552.0     0.061958
# 2259.0      0.061958
# 2413.0      0.061958
# 2121.0      0.061958
# 2372.0      0.061958
# 2838.0      0.061958
# 18061.0     0.061958
# 2862.0      0.061958
# 9756.0      0.061958
# 5294.0      0.061958
# 2437.0      0.061958
# 4071.0      0.061958
# 2956.0      0.061958
# 4648.0      0.061958
# 2804.0      0.061958
# 2439.0      0.061958
# 2856.0      0.061958
# 2933.0      0.061958
# 1091.0      0.061958
# 5151.0      0.061958
# 2863.0      0.061958
# 2858.0      0.061958
# 1129.0      0.061958
# 6735.0      0.061958
# 10883.0     0.061958
# 1611.0      0.061958
# 1393.0      0.061958
# 4768.0      0.061958
# 1274.0      0.061958
# 2561.0      0.061958
# 1563.0      0.061958
# 6388.0      0.061958
# 8376.0      0.061958
# 4841.0      0.061958
# 2074.0      0.061958
# 2972.0      0.061958
# 6815.0      0.061958
# 2690.0      0.061958
# 17567.0     0.061958
# 1569.0      0.061958
# 4187.0      0.061958
# 3306.0      0.061958
# 9602.0      0.061958
# 2127.0      0.061958
# 2340.0      0.061958
# 3617.0      0.061958
# 19237.0     0.061958
# 18844.0     0.061958
# 2552.0      0.061958
# 2678.0      0.061958
# 5171.0      0.061958
# 11916.0     0.061958
# 9380.0      0.061958
# 5878.0      0.061958
# 2468.0      0.061958
# 4127.0      0.061958
# 2148.0      0.061958
# 3886.0      0.061958
# 6667.0      0.061958
# 2090.0      0.061958
# 2086.0      0.061958
# 2684.0      0.061958
# 2318.0      0.061958
# 3022.0      0.061958
# 17159.0     0.061958
# 2809.0      0.061958
# 10854.0     0.061958
# 2571.0      0.061958
# 6142.0      0.061958
# 2496.0      0.061958
# 3419.0      0.061958
# 2501.0      0.061958
# 2566.0      0.061958
# 3920.0      0.061958
# 13964.0     0.061958
# 6540.0      0.061958
# 2244.0      0.061958
# 16184.0     0.061958
# 4233.0      0.061958
# 14814.0     0.061958
# 1951.0      0.061958
# 9724.0      0.061958
# 1878.0      0.061958
# 5238.0      0.061958
# 15992.0     0.061958
# 2370.0      0.061958
# 6781.0      0.061958
# 6653.0      0.061958
# 2851.0      0.061958
# 5258.0      0.061958
# 2476.0      0.061958
# 2285.0      0.061958
# 3448.0      0.061958
# 4558.0      0.061958
# 1702.0      0.061958
# 2564.0      0.061958
# 5070.0      0.061958
# 3780.0      0.061958
# 9824.0      0.061958
# 9985.0      0.061958
# 1200.0      0.061958
# 3388.0      0.061958
# 1420.0      0.061958
# 3038.0      0.061958
# 2322.0      0.061958
# 2926.0      0.061958
# 4505.0      0.061958
# 2835.0      0.061958
# 6553.0      0.061958
# 6673.0      0.061958
# 13591.0     0.061958
# 2177.0      0.061958
# 19517.0     0.061958
# 19202.0     0.061958
# 10048.0     0.061958
# 2723.0      0.061958
# 6644.0      0.061958
# 3161.0      0.061958
# 4739.0      0.061958
# 6272.0      0.061958
# 5021.0      0.061958
# 9924.0      0.061958
# 3069.0      0.061958
# 9241.0      0.061958
# 6472.0      0.061958
# 3055.0      0.061958
# 8321.0      0.061958
# 3143.0      0.061958
# 8578.0      0.061958
# 9888.0      0.061958
# 13341.0     0.061958
# 5677.0      0.061958
# 9526.0      0.061958
# 6825.0      0.061958
# 4424.0      0.061958
# 5441.0      0.061958
# 6074.0      0.061958
# 11245.0     0.061958
# 9714.0      0.061958
# 6172.0      0.061958
# 10124.0     0.061958
# 5309.0      0.061958
# 7654.0      0.061958
# 12808.0     0.061958
# 6586.0      0.061958
# 2519.0      0.061958
# 17099.0     0.061958
# 13120.0     0.061958
# 3131.0      0.061958
# 4444.0      0.061958
# 6674.0      0.061958
# 9852.0      0.061958
# 7446.0      0.061958
# 13757.0     0.061958
# 16598.0     0.061958
# 4285.0      0.061958
# 6146.0      0.061958
# 4668.0      0.061958
# 13664.0     0.061958
# 8500.0      0.061958
# 5363.0      0.061958
# 4081.0      0.061958
# 3578.0      0.061958
# 17328.0     0.061958
# 10793.0     0.061958
# 10851.0     0.061958
# 10466.0     0.061958
# 2362.0      0.061958
# 6439.0      0.061958
# 4385.0      0.061958
# 4066.0      0.061958
# 5206.0      0.061958
# 2655.0      0.061958
# 2570.0      0.061958
# 4502.0      0.061958
# 4639.0      0.061958
# 4534.0      0.061958
# 4319.0      0.061958
# 7094.0      0.061958
# 3564.0      0.061958
# 6261.0      0.061958
# 6804.0      0.061958
# 19436.0     0.061958
# 5472.0      0.061958
# 6385.0      0.061958
# 7525.0      0.061958
# 3660.0      0.061958
# 8740.0      0.061958
# 13499.0     0.061958
# 3491.0      0.061958
# 5220.0      0.061958
# 10252.0     0.061958
# 19740.0     0.061958
# 6209.0      0.061958
# 3348.0      0.061958
# 8412.0      0.061958
# 19197.0     0.061958
# 3210.0      0.061958
# 10475.0     0.061958
# 4721.0      0.061958
# 4615.0      0.061958
# 16959.0     0.061958
# 10306.0     0.061958
# 5406.0      0.061958
# 5902.0      0.061958
# 10855.0     0.061958
# 5914.0      0.061958
# 6646.0      0.061958
# 13973.0     0.061958
# 13320.0     0.061958
# 6687.0      0.061958
# 4735.0      0.061958
# 13872.0     0.061958
# 10266.0     0.061958
# 16064.0     0.061958
# 5674.0      0.061958
# 10447.0     0.061958
# 19232.0     0.061958
# 17169.0     0.061958
# 17174.0     0.061958
# 16595.0     0.061958
# 19973.0     0.061958
# 13402.0     0.061958
# 13206.0     0.061958
# 19545.0     0.061958
# 18041.0     0.061958
# 19246.0     0.061958
# 10748.0     0.061958
# 16752.0     0.061958
# 6201.0      0.061958
# 19845.0     0.061958
# 4001.0      0.061958
# 5067.0      0.061958
# 3692.0      0.061958
# 19847.0     0.061958
# 5747.0      0.061958
# 19187.0     0.061958
# 10008.0     0.061958
# 7988.0      0.061958
# 7083.0      0.061958
# 4723.0      0.061958
# 3407.0      0.061958
# 2929.0      0.061958
# 12031.0     0.061958
# 15427.0     0.061958
# 5126.0      0.061958
# 9619.0      0.061958
# 5010.0      0.061958
# 19033.0     0.061958
# 10400.0     0.061958
# 2793.0      0.061958
# 17123.0     0.061958
# 19190.0     0.061958
# 13577.0     0.061958
# 8943.0      0.061958
# 10422.0     0.061958
# 2348.0      0.061958
# 3072.0      0.061958
# 12490.0     0.061958
# 8020.0      0.061958
# 17068.0     0.061958
# 19272.0     0.061958
# 18213.0     0.061958
# 5577.0      0.061958
# 2691.0      0.061958
# 7403.0      0.061958
# 8823.0      0.061958
# 3579.0      0.061958
# 17779.0     0.061958
# 4968.0      0.061958
# 5147.0      0.061958
# 2718.0      0.061958
# 2389.0      0.061958
# 17584.0     0.061958
# 5661.0      0.061958
# 4869.0      0.061958
# 4649.0      0.061958
# 10496.0     0.061958
# 2768.0      0.061958
# 3408.0      0.061958
# 3755.0      0.061958
# 2187.0      0.061958
# 4258.0      0.061958
# 5326.0      0.061958
# 5485.0      0.061958
# 17639.0     0.061958
# 6062.0      0.061958
# 6288.0      0.061958
# 4000.0      0.061958
# 3815.0      0.061958
# 4930.0      0.061958
# 5265.0      0.061958
# 2705.0      0.061958
# 4448.0      0.061958
# 2379.0      0.061958
# 5487.0      0.061958
# 2810.0      0.061958
# 8938.0      0.061958
# 9936.0      0.061958
# 5454.0      0.061958
# 18740.0     0.061958
# 5473.0      0.061958
# 13503.0     0.061958
# 13549.0     0.061958
# 18172.0     0.061958
# 2774.0      0.061958
# 9439.0      0.061958
# 3424.0      0.061958
# 4194.0      0.061958
# 2532.0      0.061958
# 5666.0      0.061958
# 2226.0      0.061958
# 5561.0      0.061958
# 2897.0      0.061958
# 5321.0      0.061958
# 5410.0      0.061958
# 4850.0      0.061958
# 2001.0      0.061958
# 4404.0      0.061958
# 3944.0      0.061958
# 2960.0      0.061958
# 18947.0     0.061958
# 6465.0      0.061958
# 2683.0      0.061958
# 2014.0      0.061958
# 3441.0      0.061958
# 4284.0      0.061958
# 6513.0      0.061958
# 4213.0      0.061958
# 9204.0      0.061958
# 13726.0     0.061958
# 4107.0      0.061958
# 3597.0      0.061958
# 4115.0      0.061958
# 19999.0     0.061958
# 2517.0      0.061958
# 4373.0      0.061958
# 3377.0      0.061958
# 2064.0      0.061958
# 2430.0      0.061958
# 4877.0      0.061958
# 2013.0      0.061958
# 2974.0      0.061958
# 2766.0      0.061958
# 3702.0      0.061958
# 3989.0      0.061958
# 5098.0      0.061958
# 14411.0     0.061958
# 8237.0      0.061958
# 3211.0      0.061958
# 16704.0     0.061958
# 4774.0      0.061958
# 4568.0      0.061958
# 5993.0      0.061958
# 6499.0      0.061958
# 6397.0      0.061958
# 2725.0      0.061958
# 3622.0      0.061958
# 6180.0      0.061958
# 6274.0      0.061958
# 4381.0      0.061958
# 2559.0      0.061958
# 5488.0      0.061958
# 19586.0     0.061958
# 6549.0      0.061958
# 6842.0      0.061958
# 4249.0      0.061958
# 13570.0     0.061958
# 6712.0      0.061958
# 9991.0      0.061958
# 10248.0     0.061958
# 10938.0     0.061958
# 2593.0      0.061958
# 11878.0     0.061958
# 8095.0      0.061958
# 16856.0     0.061958
# 4537.0      0.061958
# 17924.0     0.061958
# 4014.0      0.061958
# 12742.0     0.061958
# 3376.0      0.061958
# 10482.0     0.061958
# 2514.0      0.061958
# 3196.0      0.061958
# 4087.0      0.061958
# 5368.0      0.061958
# 17399.0     0.061958
# 16885.0     0.061958
# 4323.0      0.061958
# 5155.0      0.061958
# 2936.0      0.061958
# 18789.0     0.061958
# 4883.0      0.061958
# 2029.0      0.061958
# 2996.0      0.061958
# 9278.0      0.061958
# 4162.0      0.061958
# 8853.0      0.061958
# 4876.0      0.061958
# 2141.0      0.061958
# 3936.0      0.061958
# 5204.0      0.061958
# 2973.0      0.061958
# 10761.0     0.061958
# 6502.0      0.061958
# 12936.0     0.061958
# 4221.0      0.061958
# 4963.0      0.061958
# 4200.0      0.061958
# 5006.0      0.061958
# 7639.0      0.061958
# 13525.0     0.061958
# 6322.0      0.061958
# 6349.0      0.061958
# 6380.0      0.061958
# 3102.0      0.061958
# 4556.0      0.061958
# 4230.0      0.061958
# 4859.0      0.061958
# 19431.0     0.061958
# Name: proportion, dtype: float64
# ........................
# La distribución de las categorías (incluyendo nulos) para la columna performance_rating
# performance_rating
# 3.0    74.659232
# 4.0    13.258984
# NaN    12.081784
# Name: proportion, dtype: float64
# ........................
# La distribución de las categorías (incluyendo nulos) para la columna total_working_years
# total_working_years
# NaN     32.589839
# 10.0     8.921933
# 8.0      5.328377
# 6.0      5.204461
# 9.0      4.275093
# 5.0      4.089219
# 7.0      3.469641
# 4.0      3.345725
# 1.0      3.283767
# 12.0     2.106568
# 3.0      1.982652
# 13.0     1.858736
# 14.0     1.858736
# 11.0     1.796778
# 16.0     1.734820
# 15.0     1.734820
# 20.0     1.734820
# 18.0     1.672862
# 21.0     1.425031
# 17.0     1.363073
# 2.0      1.301115
# 22.0     1.115242
# 19.0     1.053284
# 24.0     0.867410
# 23.0     0.805452
# 28.0     0.805452
# 0.0      0.495663
# 26.0     0.495663
# 36.0     0.371747
# 29.0     0.371747
# 25.0     0.371747
# 33.0     0.371747
# 37.0     0.309789
# 27.0     0.309789
# 31.0     0.247831
# 35.0     0.185874
# 32.0     0.185874
# 30.0     0.185874
# 40.0     0.185874
# 34.0     0.123916
# 38.0     0.061958
# Name: proportion, dtype: float64
# ........................
# La distribución de las categorías (incluyendo nulos) para la columna worklife_balance
# worklife_balance
# 3.0    56.567534
# 2.0    22.242875
# 4.0     9.603470
# NaN     6.691450
# 1.0     4.894672
# Name: proportion, dtype: float64
# ........................

# %%
#Primero imputamos por la mediana: worklife_balance
median_worklife_balance = df["worklife_balance"].median()
print(median_worklife_balance)

df["worklife_balance"] = df["worklife_balance"].fillna(median_worklife_balance)
# Out:
# 3.0

# %%
# otra forma de hacerlo con el SimpleImputer

#imputer = SimpleImputer(strategy='median')  # Aquí puedes elegir 'mean', 'median', 'mode", etc.
#df['worklife_balance'] = imputer.fit_transform(df[['worklife_balance']])

# %%
#Borramos la columna "performance_rating" 

df.drop("performance_rating", axis=1, inplace=True)

# %%
columnas_number_con_nulos = df[df.columns[df.isnull().any()]].select_dtypes(include = "number").columns
columnas_number_con_nulos
# Out:
# Index(['monthly_income_$', 'total_working_years'], dtype='object')

# %%
# como vamos a crear columnas nuevas, vamos a hacer una copia del DataFrame usando el método 'copy()'
df_copia = df.copy()
df_copia.head(1)
# Out:
#    age attrition business_travel  distance_from_home  education  \
# 0   51        no      non-travel                   6          3
#
#   education_field  environment_satisfaction gender  job_involvement  \
# 0         unknown                         1      M                3
#
#    job_level             job_role  job_satisfaction marital_status  \
# 0          5   research director                  3        unknown
#
#    monthly_income_$  num_companies_worked over_time  percent_salary_hike  \
# 0           19537.0                     7        No                   13
#
#    relationship_satisfaction standard_hours  stock_option_level  \
# 0                          3      full-time                   0
#
#    total_working_years  worklife_balance  years_at_company  \
# 0                  NaN               3.0                20
#
#    years_since_last_promotion  years_with_curr_manager remote_work
# 0                          15                       15         yes

# %%
# hemos dicho que para las dos columnas restantes aplicaremos los dos métodos para luego compararlos, empezaremos por el IterativeImputer
# instanciamos las clases
imputer_iterative = IterativeImputer(max_iter = 20, random_state = 42)
# ajustamos y tranformamos los datos
imputer_iterative_imputado = imputer_iterative.fit_transform(df_copia[["monthly_income_$", "total_working_years"]])
# comprobamos que es lo que nos devuelve, que en este caso es un array también
imputer_iterative_imputado
# Out:
# array([[1.95370000e+04, 3.25871610e+01],
#        [1.99990000e+04, 3.40000000e+01],
#        [1.92320000e+04, 2.20000000e+01],
#        ...,
#        [5.12921955e+03, 9.00000000e+00],
#        [6.64128693e+03, 1.20000000e+01],
#        [1.08450000e+04, 1.86484620e+01]])

# %%
# en este caso como vamos a aplicar los dos métodos sobre estas columnas vamos a crear dos columnas nuevas
df_copia[["monthly_income_$_iterative", "total_working_years_iterative"]] = imputer_iterative_imputado
# comprobamos los nulos
print(f"Después del 'Iterative' tenemos: \n{df_copia[["monthly_income_$_iterative", "total_working_years_iterative"]].isnull().sum()} nulos")
# Out:
# Después del 'Iterative' tenemos:
# monthly_income_$_iterative       0
# total_working_years_iterative    0
# dtype: int64 nulos

# %%
df_copia.head()
# Out:
#    age attrition business_travel  distance_from_home  education  \
# 0   51        no      non-travel                   6          3
# 1   52        no      non-travel                   1          4
# 2   42        no   travel_rarely                   4          2
# 3   47        no   travel_rarely                   2          4
# 4   46        no      non-travel                   3          3
#
#     education_field  environment_satisfaction gender  job_involvement  \
# 0           unknown                         1      M                3
# 1     life sciences                         3      M                2
# 2  technical degree                         3      M                3
# 3           medical                         1      F                3
# 4  technical degree                         1      F                4
#
#    job_level             job_role  job_satisfaction marital_status  \
# 0          5   research director                  3        unknown
# 1          5             manager                  3        unknown
# 2          5             manager                  4        married
# 3          4   research director                  3        married
# 4          4     sales executive                  1       divorced
#
#    monthly_income_$  num_companies_worked over_time  percent_salary_hike  \
# 0           19537.0                     7        No                   13
# 1           19999.0                     0   unknown                   14
# 2           19232.0                     1        No                   11
# 3           17169.0                     3   unknown                   19
# 4               NaN                     2        No                   12
#
#    relationship_satisfaction standard_hours  stock_option_level  \
# 0                          3      full-time                   0
# 1                          1      full-time                   1
# 2                          4      full-time                   0
# 3                          2      full-time                   2
# 4                          4      full-time                   1
#
#    total_working_years  worklife_balance  years_at_company  \
# 0                  NaN               3.0                20
# 1                 34.0               3.0                33
# 2                 22.0               3.0                22
# 3                  NaN               3.0                20
# 4                  NaN               3.0                19
#
#    years_since_last_promotion  years_with_curr_manager remote_work  \
# 0                          15                       15         yes
# 1                          11                        9         yes
# 2                          11                       15         yes
# 3                           5                        6          no
# 4                           2                        8          no
#
#    monthly_income_$_iterative  total_working_years_iterative
# 0                19537.000000                      32.587161
# 1                19999.000000                      34.000000
# 2                19232.000000                      22.000000
# 3                17169.000000                      28.789780
# 4                 6399.663531                      11.520610

# %%
# hagamos ahora lo mismo con el KNNImputer. NOTA, la ejecución de esta celda puede tardar un ratito
# instanciamos la clase del KNNImputer
imputer_knn = KNNImputer(n_neighbors = 5)
# ajustamos y transformamos los datos
imputer_knn_imputado = imputer_knn.fit_transform(df_copia[["monthly_income_$", "total_working_years"]])
# comprobamos que es lo que nos devuelve, que sigue siendo un array
imputer_knn_imputado
# Out:
# array([[1.9537e+04, 3.0000e+01],
#        [1.9999e+04, 3.4000e+01],
#        [1.9232e+04, 2.2000e+01],
#        ...,
#        [7.0506e+03, 9.0000e+00],
#        [5.2886e+03, 1.2000e+01],
#        [1.0845e+04, 1.7000e+01]])

# %%
# por último nos queda añadir ese array al DataFrame como hemos hecho hasta ahora
df_copia[["monthly_income_$_knn", "total_working_years_knn"]] = imputer_knn_imputado

# comprobamos los nulos
print(f"Después del 'KNN' tenemos: \n{df_copia[["monthly_income_$_knn", "total_working_years_knn"]].isnull().sum()} nulos")
# Out:
# Después del 'KNN' tenemos:
# monthly_income_$_knn       0
# total_working_years_knn    0
# dtype: int64 nulos

# %%
df_copia.describe()[["monthly_income_$", "monthly_income_$_iterative", "monthly_income_$_knn","total_working_years", "total_working_years_iterative", "total_working_years_knn"]]
# Out:
#        monthly_income_$  monthly_income_$_iterative  monthly_income_$_knn  \
# count        771.000000                 1614.000000           1614.000000
# mean        6477.686122                 6399.663531           6455.726816
# std         4766.119959                 3991.855967           4057.303192
# min         1009.000000                  593.017428           1009.000000
# 25%         2880.000000                 3617.152177           3641.600000
# 50%         4859.000000                 5633.242011           5986.500000
# 75%         8230.500000                 6908.750000           7284.600000
# max        19999.000000                20753.915760          19999.000000
#
#        total_working_years  total_working_years_iterative  \
# count          1088.000000                    1614.000000
# mean             11.318934                      11.520610
# std               7.727675                       7.119934
# min               0.000000                       0.000000
# 25%               6.000000                       7.000000
# 50%              10.000000                      10.000000
# 75%              15.000000                      13.000000
# max              40.000000                      40.000000
#
#        total_working_years_knn
# count              1614.000000
# mean                 11.508224
# std                   6.957940
# min                   0.000000
# 25%                   7.000000
# 50%                  10.600000
# 75%                  13.000000
# max                  40.000000

# %%
# ante esta situación, vamos a eliminar las columnas que ya no nos interesan para guardar el DataFrame para la lección de mañana. 
# en nuestro caso eliminaremos, "age", "padays", "euribor3m" (porque tienen nulos), "age_knn" y "euribor_knn" (porque para estas columnas podríamos haber eliminado cualquiera de las columnas derivadas de la imputación) y "pdays_iterative" (porque hemos visto que es la que peor imputaba los nulos)
df_copia.drop(["monthly_income_$", "monthly_income_$_knn","total_working_years", "total_working_years_knn"], axis = 1, inplace = True)
# ahora vamos a cambiar el nombre de las columnas que quedaron para que tengan el mismo nombre de origen
nuevo_nombre = {"monthly_income_$_iterative": "monthly_income_$",  'total_working_years_iterative': "total_working_years" }
df_copia.rename(columns = nuevo_nombre, inplace = True)

# %%
df_copia.head()
# Out:
#    age attrition business_travel  distance_from_home  education  \
# 0   51        no      non-travel                   6          3
# 1   52        no      non-travel                   1          4
# 2   42        no   travel_rarely                   4          2
# 3   47        no   travel_rarely                   2          4
# 4   46        no      non-travel                   3          3
#
#     education_field  environment_satisfaction gender  job_involvement  \
# 0           unknown                         1      M                3
# 1     life sciences                         3      M                2
# 2  technical degree                         3      M                3
# 3           medical                         1      F                3
# 4  technical degree                         1      F                4
#
#    job_level             job_role  job_satisfaction marital_status  \
# 0          5   research director                  3        unknown
# 1          5             manager                  3        unknown
# 2          5             manager                  4        married
# 3          4   research director                  3        married
# 4          4     sales executive                  1       divorced
#
#    num_companies_worked over_time  percent_salary_hike  \
# 0                     7        No                   13
# 1                     0   unknown                   14
# 2                     1        No                   11
# 3                     3   unknown                   19
# 4                     2        No                   12
#
#    relationship_satisfaction standard_hours  stock_option_level  \
# 0                          3      full-time                   0
# 1                          1      full-time                   1
# 2                          4      full-time                   0
# 3                          2      full-time                   2
# 4                          4      full-time                   1
#
#    worklife_balance  years_at_company  years_since_last_promotion  \
# 0               3.0                20                          15
# 1               3.0                33                          11
# 2               3.0                22                          11
# 3               3.0                20                           5
# 4               3.0                19                           2
#
#    years_with_curr_manager remote_work  monthly_income_$  total_working_years
# 0                       15         yes      19537.000000            32.587161
# 1                        9         yes      19999.000000            34.000000
# 2                       15         yes      19232.000000            22.000000
# 3                        6          no      17169.000000            28.789780
# 4                        8          no       6399.663531            11.520610

# %%
# Guardamos el DataFrame para usarlo en la lección de mañana 
df_copia.to_csv("3_HR_DATA_nulos.csv",index=False)

# %%
df = pd.read_csv("3_HR_DATA_nulos.csv")

# %% [markdown]
# # Tipo de dato

# %%
#Comprobamos el tipo de dato de cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1614 non-null   int64
#  1   attrition                   1614 non-null   object
#  2   business_travel             1614 non-null   object
#  3   distance_from_home          1614 non-null   int64
#  4   education                   1614 non-null   int64
#  5   education_field             1614 non-null   object
#  6   environment_satisfaction    1614 non-null   int64
#  7   gender                      1614 non-null   object
#  8   job_involvement             1614 non-null   int64
#  9   job_level                   1614 non-null   int64
#  10  job_role                    1614 non-null   object
#  11  job_satisfaction            1614 non-null   int64
#  12  marital_status              1614 non-null   object
#  13  num_companies_worked        1614 non-null   int64
#  14  over_time                   1614 non-null   object
#  15  percent_salary_hike         1614 non-null   int64
#  16  relationship_satisfaction   1614 non-null   int64
#  17  standard_hours              1614 non-null   object
#  18  stock_option_level          1614 non-null   int64
#  19  worklife_balance            1614 non-null   float64
#  20  years_at_company            1614 non-null   int64
#  21  years_since_last_promotion  1614 non-null   int64
#  22  years_with_curr_manager     1614 non-null   int64
#  23  remote_work                 1614 non-null   object
#  24  monthly_income_$            1614 non-null   float64
#  25  total_working_years         1614 non-null   float64
# dtypes: float64(3), int64(14), object(9)
# memory usage: 328.0+ KB

# %%
#CCorregimos el tipo de dato de las columnas que lo necesitan
df[["worklife_balance","monthly_income_$", "total_working_years"]] = df[["worklife_balance","monthly_income_$", "total_working_years"]].astype(int)

# %%
#Comprobamos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1614 non-null   int64
#  1   attrition                   1614 non-null   object
#  2   business_travel             1614 non-null   object
#  3   distance_from_home          1614 non-null   int64
#  4   education                   1614 non-null   int64
#  5   education_field             1614 non-null   object
#  6   environment_satisfaction    1614 non-null   int64
#  7   gender                      1614 non-null   object
#  8   job_involvement             1614 non-null   int64
#  9   job_level                   1614 non-null   int64
#  10  job_role                    1614 non-null   object
#  11  job_satisfaction            1614 non-null   int64
#  12  marital_status              1614 non-null   object
#  13  num_companies_worked        1614 non-null   int64
#  14  over_time                   1614 non-null   object
#  15  percent_salary_hike         1614 non-null   int64
#  16  relationship_satisfaction   1614 non-null   int64
#  17  standard_hours              1614 non-null   object
#  18  stock_option_level          1614 non-null   int64
#  19  worklife_balance            1614 non-null   int32
#  20  years_at_company            1614 non-null   int64
#  21  years_since_last_promotion  1614 non-null   int64
#  22  years_with_curr_manager     1614 non-null   int64
#  23  remote_work                 1614 non-null   object
#  24  monthly_income_$            1614 non-null   int32
#  25  total_working_years         1614 non-null   int32
# dtypes: int32(3), int64(14), object(9)
# memory usage: 309.1+ KB

# %%
# Guardamos el DataFrame para usarlo en la lección de mañana sobreescribiendo el anterior
df.to_csv("3_HR_DATA_nulos.csv",index=False)
